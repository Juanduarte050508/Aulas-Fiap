# %%
#6

par = []
impar = []
numeros = [int(input("1° numero")),int(input("2° numero")),int(input("3° numero")),int(input("4° numero")),int(input("5° numero")),int(input("6° numero")),int(input("7° numero")),int(input("8° numero")),int(input("9° numero")),int(input("10° numero"))]

for k in numeros:
    if k % 2 == 0:
     par.append(k)
    else:
     impar.append(k)
print (f"Pares, {par}")
print (f"Impares, {impar}")
# Out:
# Pares, [4, 6, 8, 2]
# Impares, [3, 5, 7, 3, 1, 9]

# %%
#7 

nome = int(input("1° Aluno, digite seu nome: ")),int(input("2° Aluno, digite seu nome: ")), int(input("3° Aluno, digite seu nome: ")), int(input("4° Aluno, digite seu nome: ")), int(input("5° Aluno, digite seu nome: "))
idade = int(input("1°Digite sua idade: "))

# %%
#8

nome = []
preço = []
listafinal = []

for listaNomes in range (100):
 digitado = input("Digite o seu nome")
 nome.append(digitado)
print (f"Essa é a lista de nomes {nome}")

for listaPreços in range (100):
 digitadoPreço = float(input("Digite o preço"))
 preço.append(digitadoPreço)
print (f"Essa é a lista de preços {preço}")

listafinal = (f"{nome} - {preço}")
print (f"Lista final {listafinal}")
# Out:
# Essa é a lista de nomes ['juan']
# Essa é a lista de preços [2.0]
# LIsta final ['juan'] - [2.0]

# %%
#9

alunos = []

for provalunos in range (4):
    nomeDigitado = input("Digite seu nome")
    notaDigitada = float(input("Digite sua nota"))
    dados =[nomeDigitado, notaDigitada]
    alunos.append(dados)

print (f"lista de alunos cadastrados: {alunos}")
# Out:
# lista de alunos cadastrados: [['Juan', 10.0], ['Victor', 8.0], ['Laura', 0.0], ['rebeca', 2.0]]

# %%
#10

contador = (0)
while contador < 20:
    contador += 1
    print (f"{contador}")

# %%
#11

soma = 0
digitado = int(input("Digite um numero"))

while digitado != 0:
    soma += digitado 
    print(digitado)
    if digitado > 0:
        print ("Digite um numero menor")
    digitado = int(input("Digite um numero"))

print (f"Soma dos numeros digitados: {soma}")

# %%
#12

soma = 0
digitado = int(input("Digite um numero"))

while digitado != 0:
    soma += digitado 
    print(digitado)
    if digitado > 0:
        print ("Digite um numero menor")
    digitado = int(input("Digite um numero"))

print (f"Soma dos numeros digitados: {soma}")

# %%
#13

for i in range (50):
    if i % 2 == 0:
     continue 
    else:
       print (f"Impares: {i}")

# %%
#14

fatorial = 1

for i in range (5, 0, -1):
    fatorial *= i
print(fatorial)

# %%
#15

lista = [3, 15, 7, 22, 9, 18, 4]

for i in lista:
    if i > 10:
        print(i)
    else:
        continue

# %%
#16

soma = 0
tentativas = 0

while soma < 100:
    idades = int(input("Digite idades"))
    tentativas += 1
    soma += idades
media = soma/tentativas

print (f"Esse foi o numero de tentativas: {tentativas}")
print (f"Esse foi o media: {media}")

# %%
#17

palavra = ("engenharia")
contador = 0 

for letra in palavra:
 if letra in "aeiou":
  contador += 1

print (contador)

# %%
#18 

soma = 0
numeros = float(input("Digite numeros"))

while numeros != 0:
    soma += numeros
    numeros = float(input("Digite numeros"))
    
print (soma)

# %%
#19

for i in range (1, 11):
    tabuada = i*7
    print (tabuada)

# %%
#20

senha = input("digite uma senha")

while senha != "python123":
    senha = input("digite uma senha")
print ("Acesso liberado")

# %%
#21 

convidados = []

for i in range (5):
    acessoConvidado = input("Digite seu nome")
    convidados.append(acessoConvidado)

print(f"Lista de convidados {convidados}")

# %%
#22

listapreços = [5.0, 12.5, 8.0, 25.0, 3.0, 15.0, 45.0]
caros = []

for i in listapreços:
    if i > 15:
        caros.append(i)
print(caros)

# %%
#23 

carrinho = []
produto = ""

while produto != "sair":

    produto = input("Digite o nome do produto")
    if produto != "sair":
        carrinho.append(produto)

print(carrinho)
