# %%
#lição 1, Àrea do Circulo//

#Variaveis
pi=3.14
raio = float(input("Insira o raio do circulo"))
R2= raio*raio

#Cálculo da área
Área = pi*R2

#Esrutura de saída
print ("A Área do circulo é", Área)
# Out:
# A Área do circulo é 314.0

# %%
#lição 2, área do retangulo//

#Variaveis
lado1= float(input('Digite o lado 1 do retangulo:'))
lado2= float(input("Digite o lado 2 do rentangulo:"))

#Calculo do retangulo
Area = lado1*lado2

#Estrutura de saída 
print("Área do retangulo", Area)
# Out:
# Área do retangulo 200.0

# %%
#lição 3, área do triangulo//

#Variaveis
Base= float(input('Digite a base do triangulo'))
Altura= float(input("Digite a altura"))

#Calculo do triangulo
Area = (Base*Altura)/2

#Estrutura de saída
print('Area do triangulo', Area)
# Out:
# Area do triangulo 6.0

# %%
#lição 4, conversão de distancia

#Variveis 
km= float (input('Digite a distancia em KM'))

#calculo da distancia 
m= km*1000
cm= m*100

#Estrutura da saida 
print('Metros', m,"m")
print("Centimetro",cm,"cm")
# Out:
# Metros 32000.0 m
# Centimetro 3200000.0 cm

# %%
#lição 5, Velocidade Media

#Variaveis
Distancia = float(input("Digite a distancia"))
Tempo = float(input("Digite o Tempo"))

#Calculo da velocidade média
Velocidade_media= Distancia/Tempo 

#Estrutura de saida 
print("Sua velocidade média é de", Velocidade_media,"Km/h")
# Out:
# Sua velocidade média é de 10.0 Km/h

# %%
#6 Calculo da energia

#Variaveis
massa= float(input("digite a massa"))
C=3*10^8


#Caluclo da Energia
Energia= massa*C

#Saida
print("A energia é:", Energia)
# Out:
# A energia é: 1540.0

# %%
#7 Calculo da hipotenusa 

#Variaveis
b= float(input("Digite o valor de B"))
c= float(input("Digite o valor de C"))

#Calculo
A=b*b+c*c
CalculoHip= A**0.5

#Saida
print("Esse é o valor da hipotenusa", CalculoHip)
# Out:
# Esse é o valor da hipotenusa 5.0

# %%
#8 Estrutura de input com String 

Nome= (input ("Digite sue nome:"))
print (Nome)

Sobrenome = (input("Digite seu sobrenome"))
print (Sobrenome)

# " " parenteses com espaço no meio é para uma variavel invisivel 
nomecompleto= Nome + " " + Sobrenome
print(nomecompleto)
# Out:
# Juan
# Duarte
# Juan Duarte

# %%
#9 Solicitação de Dados

#Variaveis 
nome= input ("Digite seu nome")
sobrenome = input("Digite seu sobrenome")
cpf= input ("Digite o seu CPF")
endereço= input("Digite seu enderço")
cep= input("Digite o seu CEP")

#Saida
print (nome + " " + sobrenome)
print(nome + " " + sobrenome + " " + cpf)
print(endereço + " "+ cep)
# Out:
# Israelitta Labubu
# Israelitta Labubu 123321
# Casa do kraio 67

# %%
#10 Equiação 2° Grau

a= 10 
b= 3
c= 1

#Calculo
delta= b*b -4*a*c
bhaskaraX1 = (-b + delta**0.5)/(2 * a)
bhaskaraX2 = (-b - delta**0.5)/(2 * a)

#Saida
print(delta)
print("Valor positivo de Bhaskara", bhaskaraX1)
print("Valor negativo de Bhaskara", bhaskaraX2)
# Out:
# -31
# Valor positivo de Bhaskara (-0.14999999999999997+0.27838821814150105j)
# Valor negativo de Bhaskara (-0.15000000000000002-0.27838821814150105j)

# %%
   #Estrutura de condção

idade = 16
#se
if idade >= 18:
    print("Maior de idade!")

#Outra condição que não cai nem na primaria nem 
elif 18< idade <= 40:
    print ("Jovem Adulto!")
    
#senão
else:
    print ("Menor de idade")
# Out:
# Maior de idade!

# %%
#Exercicio 11

#Variaveis
nome = "Juan"
sobrenome = "Duarte"
idade= 40

#Condição
if nome == "Juan" and sobrenome == "Duarte" and idade == 40:
    print ("Seja bem vindo!")
else: print ("Acesso negado!")
# Out:
# Seja bem vindo!

# %%
#12 desbloqueador de acesso

#entrada 
Dignome = input ("Digite o seu nome")
Digsobrenome = input ("Digite seu sobrenome")
Digcpf = int(input("DIgite seu CPF"))

#Condição 
if Dignome == "Juan" and Digsobrenome == "Duarte" and Digcpf == 54781878873:
    print("Acesso VIP permitido")

elif Dignome == "Juan" and Digsobrenome == "Duarte":
    print("Verificando Cpf")

elif Digsobrenome == "Duarte" or Dignome == "Juan" and Digcpf == 54781878873:
    print("Verificação em andamento")

else: print("Acesso negado!")
# Out:
# Acesso negado!

# %%
#13 Calculo do desconto do INSS

#Entrada
salario = float(input("Digite seu salario"))

#condição
if (salario <= 1621.00): 
    desconto = salario*0.075
    salariofinal=salario-desconto

    print ("Seu desconto é de 7,5%. E o valor descontado é de", desconto, "R$","e seu salario final é de", salariofinal, "R$")
elif ( 2902.84 >= salario >= 1621.00):
    desconto = salario*0.090
    salariofinal= salario-desconto
    print ("Seu desconto é de 9,0%. E o valor descontado é de", desconto, "R$", "e seu salario final é de",salariofinal, "R$" )

elif (4354.27 >= salario >= 2902.84 ):
    desconto = salario*0.090
    salariofinal= salario-desconto
    print ("Seu desconto é de 9,0%. E o valor descontado é de", desconto, "R$", "e seu salario final é de",salariofinal, "R$" )

elif (8475.55 >= salario >= 4354.27): 
    desconto = salario*0.12
    salariofinal = salario-desconto
    print("Seu desconto é de 12,0%. E o valor descontado é de", desconto, "R$", "e seu salario final é de",salariofinal, "R$" )

elif (8475.55 < salario): 
    desconto = salario*0.14
    salariofinal = salario-desconto
    print("Seu desconto é de 14,0%. E o valor descontado é de", desconto, "R$", "e seu salario final é de",salariofinal, "R$" )
# Out:
# Seu desconto é de 14,0%. E o valor descontado é de 1400.0000000000002 R$ e seu salario final é de 8600.0 R$
