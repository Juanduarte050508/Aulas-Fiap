# %%
comando = input("Digite um star ou stop: ")

match comando:
    case "start":
        print("Cadastrar")
    case "stop":
        print("parando")
    case _:
        print("Entrada inválida!")

# %%
dados = ("produto", "arroz", 10)

match dados:
    case ("produto," nome, qtd)
        print(f{nome} - {qtd})
    case _:
        print("Entrada inválida!")

# %%
lista = [1, 2, 3]

match lista:
    case [1, 2, 3]:
        print("lista correta")
    case _:
        print("Lista incorret")

# %%
def somar(a, b)
    
    somar = a + b
    sub = a - b
    div = a / b
    mult = a * b

    return somar, sub, div, mult

a, b, c, d, = somar(int(input(()10,20), int(input())))

print(a)
print(b)
print(c)
print(d)

# %%
Grau_Celsius = float(input("Digite a tempartura"))

def Celsius_Farenheit(Grau):
     fahrenheit = Grau * 1.8 + 32
     return fahrenheit

resultado = Celsius_Farenheit(Grau_Celsius)

print(f"{Grau_Celsius}°C equivale a {resultado}°F")
# Out:
# 50.0°C equivale a 10.0°F

# %%
def calc_area_perrimetro(tipo):

    tipo= int(input("Digite 1. Circulo e 2 Retângulo: "))

    match tipo:
        case 1:
            raio= float(input("Digite o valor do raio:"))
            area = 3.1415 * raio**2
            print(area)
        case 2:
            comp = flo0at(input("Digite valor do comprimento: "))
            larg = float(input("Digite o valor da largura"))

# %%
import pandas as pd
import matplotlib.pyplot as plt

dados = {"Dia": ["Seg", "Ter", "Qua"], "Temperatura": [22, 25, 27]}
df = pd.DataFrame(dados)
print(df)

df["Temperatura"].value_counts().plot(kind="bar")
plt.show()
# Out:
#    Dia  Temperatura
# 0  Seg           22
# 1  Ter           25
# 2  Qua           27
