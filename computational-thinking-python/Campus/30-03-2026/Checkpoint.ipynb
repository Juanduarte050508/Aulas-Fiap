# %%
numeroDig1 = float(input("Digite o primeiro numero: "))
numeroDig2 = float(input("Digite o segundo numero: "))
tipooperacao = input("Qual tipo de operação gostaria de realizar (+, -, *, /): ")

if tipooperacao == "+":
    soma = numeroDig1 + numeroDig2
    print(soma)
elif tipooperacao == "-":
    subtração = numeroDig1 - numeroDig2
    print(subtração)
elif tipooperacao == "*":
    multiplicação = numeroDig1 * numeroDig2
    print(numeroDig1 * numeroDig2)
elif tipooperacao == "/":
    divisão = numeroDig1 / numeroDig2
    print(numeroDig1 / numeroDig2)
else:
    print("Você precisa escolher uma operação válida (+, -, *, /)")
# Out:
# Você precisa escolher uma operação válida (+, -, *, /)
# Subtração: -1.0
# Multiplicação: 2.0
# Divisão: 0.5
