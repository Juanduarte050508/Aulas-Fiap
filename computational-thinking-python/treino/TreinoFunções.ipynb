// %%
//Criar uma função que exibe "Olá, mundo!" no console.

function BoasVindas ();
    console.log("Olá mundo");
// Out:
// Olá

// %%
//Criar uma função que recebe um nome como parâmetro e exibe "Olá, [nome]!" no console.

let nomedigitado =  prompt("Digite seu nome");
function OláUsuario(){};
console.log(`Olá ${nomedigitado}`);
// Out:
// Olá string

// %%
//Criar uma função que recebe um número como parâmetro e retorna o dobro desse número.

let numeroDigitado = parseFloat(prompt("Digite um numero"));

function DobroNumero(numero){
let calculo = numero*2
return calculo
};

console.log (DobroNumero(numeroDigitado));
// Out:
// 20

// %%
//Criar uma função que recebe três números como parâmetros e retorna a média deles.

let numero3 = parseFloat(prompt("Digite um numero"));
let numero1 = parseFloat(prompt("Digite um numero"));
let numero2 = parseFloat(prompt("Digite um numero"));

function media(numero1, numero2, numero3) {
let calculo = (numero1 + numero2 + numero3)/3
return calculo 
};

console.log(media(numero1, numero2, numero3));
// Out:
// 11
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %%
//Criar uma função que recebe dois números como parâmetros e retorna o maior deles.

let numero1 = parseFloat(prompt("Digite um numero"));
let numero2 = parseFloat(prompt("Digite um numero"));

function NumeroMaior(numero1, numero2){
    if (numero1 > numero2)
        return numero1
    else
        return numero2
};

console.log (`O numero maior é ${NumeroMaior(numero1, numero2)}`);
// Out:
// O numero maior é 5000

// %%
//Criar uma função que recebe um número como parâmetro e retorna o resultado da multiplicação desse número por ele mesmo

let numero = parseFloat(prompt("Digite um numero"));

function AoQuadrado(numero){
let calculo = numero*numero
return calculo;
}
console.log (`O numero ${numero} ao quadrado é = ${AoQuadrado(numero)}`)
// Out:
// O numero 12 ao quadrado é = 144
